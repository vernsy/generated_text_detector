# %%
import sys

# make it possible to find the data python module in parent folder
sys.path.insert(0, '../..')
from setup.config import GPT_API_KEY

OPENAI_API_KEY= GPT_API_KEY
DAY_OF_PROGRAM_EXECUTION = 1 # 1 or more
MAX_PER_RUN = 190 # default: 190

prompt_path = "../e_llama_text_generation/prompts/prompts_springernature.jsonl" 
out_path = "./gpt_generated_springernature_23.tsv"
print(f'input file: {prompt_path}')
print(GPT_API_KEY)
# Out:
# input file: ../e_llama_text_generation/prompts/prompts_springernature.jsonl
# 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

# %%
import os
from openai import OpenAI
import tkinter as tk
from math import *

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)
def gpt3(gpt_prompt,characters):
    #gpt_prompt="Student:"+student+"\nReflektionshilfe:"
    chat_completion = client.chat.completions.create(
        messages=[
        {
            "role": "user",
            "content": 'Given two sentences, continue this text in German for about '+str(characters)+'. Sentences: '+gpt_prompt,
        }
    ],
    model="gpt-3.5-turbo",
    temperature=0.6,
    max_tokens=256,
    top_p=0.4,
)
    return chat_completion.choices[0].message.content

# %%
import nltk
import random

from typing import List
import argparse
import json

GERMAN_AVERAGE_SENTENCE_LENGTH = 25

def cut_at_character_n(text, num_characters):
    # randomize if generated text is longer or shorter than original
    randomizer = random.choice([-1, 1])*GERMAN_AVERAGE_SENTENCE_LENGTH
    cutted_text = text[:num_characters+randomizer] # if longer than text, python can handle it
    return cutted_text

def cut_at_last_complete_sentence(text):
    sentences = nltk.sent_tokenize(text)
    cut_text = ' '.join(sentences[:-1])
    return cut_text



temperature = 0.6
max_seq_len = 128
max_gen_len = 64
max_batch_size  = 4 


# calculate maximal sequence length of the input once
max_seq_len = 0
convert_to_int_or_zero = lambda value: int(value) if str(value).isdigit() else 0

with open(prompt_path, 'r', encoding='utf-8') as input_file:
        for line in input_file:
            try:
                json_data = json.loads(line)
                curr_seq_len_str = json_data["input_seq_len"]
                curr_seq_len = convert_to_int_or_zero(curr_seq_len_str)
                if curr_seq_len > max_seq_len:
                    max_seq_len = curr_seq_len
            except json.JSONDecodeError:
                print(f"Error decoding JSON: {line}")
        
        print(f"Maximal sequence length for the generator input is {max_seq_len}.")

all_prompts=[]
max_gen_lens=[]
with open(prompt_path, 'r', encoding='utf-8') as input_file:
    with open(out_path, 'w') as f_out:
        line_index = 0
        for line in input_file:
            if line_index <= 190*DAY_OF_PROGRAM_EXECUTION:
                line_index += 1
                continue

            try:
                json_data = json.loads(line)
                prompt = json_data["prompt"]
                max_gen_len_str = json_data["text_len"] # should be quite es much as the corresponding text
            except json.JSONDecodeError:
                print(f"Error decoding JSON: {line}")

            max_gen_len = convert_to_int_or_zero(max_gen_len_str)
            #prompts: List[str] = [prompt]

            # iterate through each prompt, because we want to adopt "max_gen_len" 
            # values, dependant on the prompt input

            #print(f"Maximal sequence length for the generator input is {max_seq_len}.")
            all_prompts.append(prompt)
            max_gen_lens.append(max_gen_len)
            #results = model.generate(prompts[0], max_tokens=max_gen_len,temp=0.6, top_p=0.4)
            #print(results)
            #result_dict = results[0] # always just one result
            #result_raw = next(iter(result_dict.values()))
            #result_one_line = results.replace('\n', ' ')
            #result_stripped = result_one_line.strip()
            #cutted_result = cut_at_character_n(result_stripped,max_gen_len)
            #result_complete_sentences = cut_at_last_complete_sentence(cutted_result)

            #text_len = len(result_complete_sentences)
            #line_to_write = {'prompt':prompt,'llama_text':result_complete_sentences,'gen_text_len':text_len,'orig_text_len':max_gen_len_str} 
            #print(line_to_write)         

            #f_out.write(str(line_to_write) + '\n')                        
            #line_index += 1
            #print(line_index)
# Out:
# Maximal sequence length for the generator input is 6750.

# %%
len(all_prompts),len(max_gen_lens)
#old_length = 1122333
#old_length - 190
# Out:
# (1120622, 1120622)

# %%
rpd=MAX_PER_RUN % 190 # should never be more than 200, because more will cost!
rpm=3

# %%
results=[]

# %%
import time

# %%
cpt=0
for prompt,max_gen_len in zip(all_prompts[:rpd],max_gen_lens[:rpd]):
    if cpt!=0 and cpt % rpm == 0:
        # If it's the third iteration, wait for a minute
        time.sleep(70)
    output=gpt3(prompt,max_gen_len)
    results.append(output)
    print(output)
    print(cpt)
    cpt+=1
# Out:
# Das Tonusasymmetrie-Syndrom (TAS) ist eine häufige sensomotorische Störung bei Säuglingen, die auch als Säuglingsskoliose oder umgangssprachlich als KISS bekannt ist. Diese Störung ist ein typisches Beispiel für eine dysfunktionell bedingte Störung, bei der es zu einer Asymmetrie der Muskelspannung kommt. Durch diese Asymmetrie können verschiedene Probleme auftreten, wie zum Beispiel eine Verformung der Wirbelsäule oder eine eingeschränkte Beweglichkeit.
#
# Die entwicklungsneurologische Indikation ist eine neue Erweiterung des Konzepts der Manuellen Medizin, die es ermöglicht, Kinder mit sensomotorischen Störungen zu behandeln. Dabei wird der Fokus auf die neurologische Entwicklung des Kindes gelegt und gezielte Techniken angewendet, um die muskuläre Balance und die Bewegungsfähigkeit zu verbessern.
#
# Die Manuelle Medizin bietet somit eine ganzheitliche Behandlungsmethode für Kinder mit sensomotorischen Störungen wie dem Tonus
# 0
# Dazu gehören unter anderem Pressemitteilungen, Fachartikel, Informationsbroschüren, Social-Media-Kampagnen und direkte Kommunikation mit Ärztinnen und Ärzten. Die breite Öffentlichkeit wird über Werbung in verschiedenen Medienkanälen informiert, um das Bewusstsein für bestimmte Krankheiten oder Medikamente zu schärfen.
#
# Journalistinnen und Journalisten erhalten regelmäßig Pressemitteilungen und werden zu Pressekonferenzen eingeladen, um über aktuelle Entwicklungen in der Pharmabranche zu berichten. Entscheidungsträger wie Politiker und Behördenvertreter werden gezielt angesprochen, um sie über neue Medikamente oder Therapieansätze zu informieren und mögliche Kooperationen zu besprechen.
#
# Für Patientinnen und Patienten werden Informationsbroschüren und Patientenleitfäden erstellt, die ihnen helfen, sich über ihre Krankheit und mögliche Behandlungsmöglichkeiten zu informieren. Zudem werden sie über Social-Media-Kanäle und Online-Foren erre
# 1
# Sie suchen nach alternativen Heilmethoden oder natürlichen Heilmitteln, um ihre Beschwerden zu lindern. Diese Menschen haben oft das Gefühl, dass die Schulmedizin ihre Probleme nicht ernst nimmt oder nicht die richtige Lösung bietet. Sie sind auf der Suche nach ganzheitlichen Ansätzen, die Körper, Geist und Seele gleichermaßen berücksichtigen.
#
# Einige von ihnen wenden sich beispielsweise der Homöopathie zu, einer alternativen Heilmethode, die auf dem Prinzip der Ähnlichkeit beruht. Andere wiederum setzen auf die Kraft der Natur und vertrauen auf pflanzliche Heilmittel wie Kräuter oder ätherische Öle. Es gibt auch Menschen, die sich für alternative Therapien wie Akupunktur, Osteopathie oder Chiropraktik entscheiden.
#
# Für viele ist es ein langer und oft mühsamer Weg, die richtige alternative Heilmethode zu finden. Sie probieren verschiedene Ansätze aus, machen Erfahrungen und hören auf ihren Körper. Manche finden tatsächlich Linderung und sind dankbar für die
# 2
# Comenius war der Überzeugung, dass die Menschheit durch die Ausübung brüderlicher Liebe in der Lage sein würde, eine Gesellschaft zu schaffen, die frei von Konflikten und Ungerechtigkeiten ist. Seine chiliastischen Vorstellungen über ein neues Millennium basierten auf der Idee, dass die Menschen durch ihre Liebe zueinander in der Lage sein würden, eine harmonische und gerechte Welt zu erschaffen.
#
# Um diese Prophezeiung des neuen Millenniums zu verwirklichen, betonte Comenius die Bedeutung der brüderlichen Liebe. Er glaubte, dass die Menschen lernen sollten, einander bedingungslos zu lieben und sich gegenseitig zu unterstützen. Nur durch diese liebevolle Beziehung könnten sie eine fast utopische Gesellschaft erreichen, in der Frieden und Gerechtigkeit herrschen.
#
# Comenius war sich bewusst, dass die Umsetzung dieser Vorstellungen nicht einfach sein würde. Es erforderte eine grundlegende Veränderung in der Denkweise und im Verhalten der Menschen. Sie mussten lernen, ihre egoistischen Interessen
# 3
# In Blumenbergs Analyse wird die Neugierde als eine grundlegende menschliche Eigenschaft betrachtet, die nicht nur den Drang nach Wissen hervorbringt, sondern auch die Fähigkeit des Menschen, sich über die Aufklärung hinaus zu erheben und die Neugierde in eine theoretische Ebene zu überführen. Diese offene und unbestimmte Natur der Neugierde ermöglicht es dem Menschen, sich ständig weiterzuentwickeln und neue Erkenntnisse zu gewinnen.
#
# Blumenberg betont, dass die Neugierde nicht nur ein individuelles Phänomen ist, sondern auch eine gesellschaftliche Dimension hat. Sie treibt den Menschen dazu an, sich mit anderen auszutauschen, Wissen zu teilen und gemeinsam nach Antworten auf Fragen zu suchen. Die Neugierde ist somit ein Motor für den Fortschritt und die Entwicklung der Gesellschaft.
#
# In ihrem Grußwort zur Tagung betont Ursula Reitemeyer die Bedeutung von Blumenbergs geschichtsphilosophischer Analyse der Neugierde. Sie hebt hervor, dass die Neugier
# 4
# Die PR umfasst verschiedene therapeutische Maßnahmen, die darauf abzielen, die Lungenfunktion zu verbessern, die Atemmuskulatur zu stärken und die Lebensqualität der Betroffenen zu steigern. Dabei spielen sowohl körperliche als auch psychosoziale Aspekte eine wichtige Rolle.
#
# Durch regelmäßiges Training der Atemmuskulatur und gezielte Atemübungen kann die Lungenfunktion gesteigert werden. Dies führt zu einer besseren Sauerstoffversorgung des Körpers und einer erhöhten Belastbarkeit im Alltag. Zudem werden durch die PR auch die Atemwege gereinigt und Schleim abtransportiert, was zu einer Verringerung von Husten und Auswurf führt.
#
# Neben den körperlichen Aspekten wird auch der psychosoziale Bereich in der PR berücksichtigt. Durch gezielte Schulungen und Beratungen lernen die Betroffenen, mit ihrer Erkrankung umzugehen und ihren Alltag besser zu bewältigen. Zudem werden Äng
# 5
# Diese Gedenkstätten dienen dazu, an vergangene Ereignisse zu erinnern und die Erinnerung an die Opfer wachzuhalten. Sie sind ein wichtiger Teil des kollektiven Gedächtnisses und sollen dazu beitragen, dass sich solche schrecklichen Ereignisse nicht wiederholen. In Bosnien-Herzegowina und Kroatien gibt es aufgrund der Kriege in den 1990er Jahren eine Vielzahl solcher Gedenkstätten. Sie erinnern an die Opfer von Massakern, ethnischen Säuberungen und anderen Gräueltaten, die während dieser Zeit begangen wurden.
#
# Diese Denkmäler sind oft sehr eindrucksvoll gestaltet und dienen als Mahnmal für diejenigen, die ihr Leben verloren haben. Sie sollen auch dazu beitragen, dass die Täter zur Rechenschaft gezogen werden und die Wahrheit über die Geschehnisse ans Licht kommt. Viele dieser Gedenkstätten sind öffentlich zugänglich und bieten den Besuchern die Möglichkeit, sich mit der Geschichte auseinanderzusetzen und zu
# 6
# Es wird erläutert, dass die „Mitte“-Studien darauf abzielen, die Einstellungen und Meinungen der Bevölkerung in Bezug auf rechtsextreme Tendenzen zu erfassen und zu analysieren. Dabei wird der Begriff „Mitte“ als eine Art Referenzpunkt verwendet, um die politische Orientierung und die Einstellungen der Menschen zu messen.
#
# Die Studien basieren auf einer breiten Datenbasis, die durch Umfragen und Befragungen erhoben wurde. Dabei wurden verschiedene Aspekte der rechtsextremen Einstellung untersucht, wie beispielsweise die Ablehnung von Minderheiten, die Zustimmung zu autoritären Strukturen und die nationalistische Gesinnung.
#
# Die Ergebnisse der Studien zeigen, dass rechtsextreme Einstellungen in Deutschland nach wie vor existieren und in Teilen der Bevölkerung verbreitet sind. Es wird deutlich, dass diese Einstellungen nicht nur in extremistischen Randgruppen anzutreffen sind, sondern auch in der sogenannten „Mitte“ der Gesellschaft.
#
# Besonders besorgniserregend ist dabei,
# 7
# Das Assessment umfasst eine gründliche Anamnese, bei der der Physiotherapeut Informationen über die Krankheitsgeschichte, die aktuellen Beschwerden und die individuellen Ziele des Patienten sammelt. Dabei werden auch mögliche Risikofaktoren wie Vorerkrankungen, Medikamenteneinnahme oder berufliche Belastungen berücksichtigt.
#
# Zusätzlich werden klinische Tests durchgeführt, um die Beweglichkeit, Kraft, Koordination und Sensibilität des betroffenen Bereichs zu überprüfen. Hierbei kommen standardisierte Verfahren zum Einsatz, die eine objektive Beurteilung ermöglichen. Diese Tests helfen dabei, die Schwere der Erkrankung einzuschätzen und den Therapiebedarf festzulegen.
#
# Des Weiteren werden Fragebögen eingesetzt, um Informationen über die Lebensqualität, den Funktionsstatus und die Schmerzintensität des Patienten zu erfassen. Diese Fragebögen dienen als Ergänzung zu den klinischen Tests und ermöglichen eine umfassende Beurteilung des Gesundheitszustands.
#
# Nach Abschluss des
# 8
# Heidenstam, auch bekannt als Carl Gustaf Verner von Heidenstam, war ein schwedischer Schriftsteller und Maler. Nach seinem Studium der Malerei in Paris und Rom unternahm er ausgedehnte Studienreisen, die ihn durch ganz Europa führten. Im Jahr 1912 wurde er Mitglied der Schwedischen Akademie, einer renommierten Institution für Literatur und Sprache.
#
# Heidenstam war auch Mitbegründer der Tageszeitung Svenska Dagbladet, für die er regelmäßig schrieb. Als programmatischer Vertreter der schwedischen Neuromantik prägte er die literarische Szene seiner Zeit. Er verfasste Romane, Novellen, Essays und Gedichte, die von der Natur, der Geschichte und der schwedischen Kultur inspiriert waren.
#
# Sein Schaffen wurde 1916 mit dem Nobelpreis für Literatur gewürdigt. Diese Auszeichnung unterstrich seine Bedeutung als einer der bedeutendsten Schriftsteller Schwedens. Heidenstams Werke zeichnen sich durch ihre poetische Sprache, ihre tief
# 9
# Nur so kannst Du sicherstellen, dass Du alle möglichen Lösungsansätze in Betracht ziehst und keine wichtigen Informationen übersehen wirst. Eine gründliche Vorbereitung ist der Schlüssel zum Erfolg. Dabei solltest Du nicht nur auf das Offensichtliche achten, sondern auch alternative Perspektiven einnehmen. Oftmals liegen die besten Lösungen außerhalb der gewohnten Pfade.
#
# Öffne Deinen Horizont bedeutet auch, sich von alten Denkmustern zu lösen und neue Ideen zuzulassen. Sei offen für Veränderungen und bereit, aus Deiner Komfortzone herauszutreten. Manchmal sind es gerade die ungewöhnlichen Wege, die zu den besten Ergebnissen führen.
#
# Doch Vorsicht ist geboten, denn ungewöhnliche Wege können auch mit Risiken verbunden sein. Daher ist es umso wichtiger, sich gründlich vorzubereiten. Recherchiere, sammle Informationen und hole Dir Rat von Experten ein. Je besser Du vorbereitet bist, desto größer ist Deine Chance auf Erfolg.
#
#
# 10
# eine chirurgische Intervention haben zu einer verbesserten Lebensqualität und einer Reduzierung von Komplikationen bei diesen Patienten geführt.
#
# Die Pharmakotherapie spielt eine entscheidende Rolle in der Behandlung neurogener Blasen bei Kindern und Jugendlichen. Durch die Verabreichung von Medikamenten wie Anticholinergika oder Alpha-Blockern kann die Blasenfunktion reguliert und die Symptome wie Harninkontinenz oder überaktive Blase gelindert werden. Diese Medikamente wirken auf die Muskulatur der Blase und ermöglichen eine bessere Kontrolle über die Blasenentleerung.
#
# Ein weiterer wichtiger Bestandteil der Behandlung ist der intermittierende Einmalkatheterismus (CIC). Dabei wird regelmäßig ein Einmalkatheter in die Blase eingeführt, um den Urin abzulassen. Dies hilft, Harnstauungen zu vermeiden und das Risiko von Harnwegsinfektionen zu reduzieren. Kinder und Jugendliche können den CIC selbstständig durchführen
# 11
# Vaskuläre Tumoren sind abnormal wachsende Gewebe, die in zwei Hauptkategorien unterteilt werden: Angiome und Hamartome. Angiome sind Proliferationen von Endothelzellen, die das innere Auskleidungsgewebe der Blutgefäße bilden. Sie können in verschiedenen Organen auftreten und werden oft als gutartig betrachtet. Im engeren Sinne bezieht sich der Begriff "Angiome" auf Tumoren, die ausschließlich aus Endothelzellen bestehen.
#
# Auf der anderen Seite sind Hamartome Fehlbildungen, bei denen verschiedene Gewebetypen in abnormaler Weise zusammenwachsen. Im Gegensatz zu Angiomen enthalten Hamartome nicht nur Endothelzellen, sondern auch andere Zelltypen, die normalerweise in dem betroffenen Organ vorkommen. Diese Fehlbildungen können in verschiedenen Organen auftreten und verursachen oft keine Symptome, es sei denn, sie werden groß genug, um Druck auf umliegendes Gewebe auszuüben.
#
#
# 12
# Diese disruptiven Veränderungen sind durch technologische Innovationen und neue Geschäftsmodelle gekennzeichnet, die etablierte Unternehmen und Märkte grundlegend verändern können. Ein Beispiel dafür ist die Musikindustrie, die durch die Digitalisierung und den Aufstieg von Streaming-Diensten wie Spotify und Apple Music einen starken Wandel erfahren hat. Traditionelle Vertriebswege wie CDs und Plattenläden wurden weitgehend durch den digitalen Vertrieb ersetzt, was zu einem Rückgang der Umsätze und einer Neuausrichtung der Branche führte.
#
# Aber nicht nur die Musikindustrie ist betroffen. Auch in anderen Bereichen wie dem Einzelhandel, der Automobilindustrie und dem Bankensektor sind disruptive Veränderungen zu beobachten. Online-Shopping hat den stationären Handel stark beeinflusst und zu einer Verlagerung der Umsätze ins Internet geführt. Elektroautos und autonomes Fahren stellen die traditionelle Automobilindustrie vor große Herausforderungen, da neue Wettbewerber wie Tesla mit innovativen Technologien auf den Markt dräng
# 13
# Die Gründungsinitiativen müssen sich zunächst mit der Schulaufsichtsbehörde in Verbindung setzen und ihre Pläne für die Errichtung einer Freien Alternativschule vorlegen. Dabei müssen sie detaillierte Informationen über das pädagogische Konzept, die Lehrpläne und die organisatorischen Strukturen der Schule bereitstellen. Die Schulaufsicht prüft dann diese Unterlagen und entscheidet, ob die vorgelegten Pläne den gesetzlichen Anforderungen entsprechen.
#
# Oftmals kommt es während dieses Aushandlungsprozesses zu Diskussionen und Verhandlungen zwischen den Gründungsinitiativen und der Schulaufsicht. Dabei geht es vor allem um Fragen der Finanzierung, der personellen Ausstattung und der räumlichen Voraussetzungen für die Schule. Die Gründungsinitiativen müssen überzeugend darlegen, dass sie in der Lage sind, eine qualitativ hochwertige Bildung zu gewährleisten und die gesetzlichen Vorgaben einzuhalten.
#
# Ein weiteres Problem, das sich bei den formalen Genehmig
# 14
# Hierbei muss der Tragwerksplaner verschiedene Faktoren berücksichtigen, wie zum Beispiel die Art der Belastung, die auf die Gebäudehülle wirkt, sowie die Beschaffenheit des Baugrunds. Zunächst erfolgt eine genaue Analyse der geplanten Nutzung des Gebäudes, um die erforderlichen Lasten zu ermitteln.
#
# Anschließend werden verschiedene Tragwerkssysteme in Betracht gezogen, die den Anforderungen gerecht werden. Dabei spielen sowohl statische als auch dynamische Belastungen eine Rolle. Je nach Größe und Form des Gebäudes können verschiedene Tragwerksarten wie Stahlbeton, Stahl oder Holz zum Einsatz kommen.
#
# Der Tragwerksplaner entwirft dann das Tragwerk unter Berücksichtigung der architektonischen Vorgaben und der technischen Anforderungen. Dabei müssen nicht nur die Lasten auf das Tragwerk, sondern auch die Lasten, die das Tragwerk auf den Baugrund überträgt, berücksichtigt werden. Hierbei ist es wichtig, dass das Tragwerk stabil
# 15
# Quantenphänomene sind ein faszinierendes Gebiet der Forschung, das in den letzten Jahrzehnten zu bahnbrechenden Erkenntnissen geführt hat. Sie haben dazu beigetragen, unser Verständnis der Ordnungsmechanismen in Materialien mit korrelierten Elektronen zu verbessern und haben somit einen großen Einfluss auf die moderne Technik.
#
# Ein Beispiel für eine Innovation, die auf den Erkenntnissen der Quantenphänomene basiert, ist der Quantencomputer. Durch die Nutzung von Quanteneffekten wie Superposition und Verschränkung ermöglicht er eine völlig neue Art der Informationsverarbeitung. Quantencomputer haben das Potenzial, komplexe Berechnungen in kürzester Zeit durchzuführen und könnten somit viele bisher unlösbare Probleme lösen.
#
# Aber nicht nur in der Computertechnologie haben Quantenphänomene zu Innovationen geführt. Auch in der Medizin und der Materialforschung spielen sie eine wichtige Rolle. Durch das Verständnis der quantenmechanischen Eig
# 16
# Dieser beeindruckende Mensch, namens Dr. Friedrich Müller, öffnete Götz Rehn die Augen für eine völlig neue Welt jenseits der traditionellen Medizin. Durch zahlreiche Gespräche und Diskussionen erfuhr Götz von den Lehren der Anthroposophie, einer spirituellen Bewegung, die sich mit der Erforschung der nicht-sinnlichen Welt befasst.
#
# Fasziniert von den Ideen und Erkenntnissen, die er durch Dr. Müller gewonnen hatte, beschloss Götz, sein Medizinstudium vorerst auf Eis zu legen und sich stattdessen intensiv mit der Anthroposophie auseinanderzusetzen. Er tauchte tief in die Werke von Rudolf Steiner ein, dem Begründer der Anthroposophie, und begann, sich mit den verschiedenen Aspekten der nicht-sinnlichen Welt zu beschäftigen.
#
# Götz erkannte schnell, dass die Anthroposophie nicht nur eine spirituelle Lehre war, sondern auch einen ganzheitlichen Ansatz für das Verständnis von Gesundheit und Krankheit bot. Er lernte, dass der Mens
# 17
# Bildung ist ein grundlegender Bestandteil jeder Gesellschaft und spielt eine entscheidende Rolle bei der Entwicklung und Entfaltung eines Individuums. Sie umfasst nicht nur den Erwerb von Wissen und Fertigkeiten, sondern auch die Vermittlung von Werthaltungen und Einstellungen, die für das Zusammenleben in einer Gesellschaft von Bedeutung sind.
#
# Die Bildung beginnt bereits in der frühen Kindheit und setzt sich während des gesamten Lebens fort. Sie erfolgt nicht nur in formalen Bildungseinrichtungen wie Schulen und Universitäten, sondern auch in informellen Kontexten wie Familie, Freizeitaktivitäten und der Interaktion mit anderen Menschen.
#
# Die Vermittlung von Werthaltungen spielt eine wichtige Rolle, da sie den Menschen dabei hilft, moralische und ethische Entscheidungen zu treffen. Sie umfasst die Entwicklung von Empathie, Toleranz, Respekt und Verantwortungsbewusstsein gegenüber anderen Menschen und der Umwelt. Werthaltungen werden nicht nur durch Worte vermittelt, sondern auch durch Vorbilder und das persönliche Verhalten der
# 18
# Der bestandsgeregelte Teil umfasst alle Arbeitsstationen vor dem Engpassarbeitssystem, die durch die Engpass-Steuerung gesteuert werden. Hier werden die Aufträge entsprechend der Verfügbarkeit von Material und Ressourcen freigegeben. Sobald das Engpassarbeitssystem einen Auftrag fertiggestellt hat, wird ein neuer Auftrag für die Fertigung freigegeben.
#
# Der nicht bestandsgeregelte Teil umfasst alle Arbeitsstationen nach dem Engpassarbeitssystem. Hier werden die Aufträge unabhängig von der Verfügbarkeit von Material und Ressourcen freigegeben. Die Engpass-Steuerung konzentriert sich ausschließlich auf die Steuerung des Engpassarbeitssystems und stellt sicher, dass dieses kontinuierlich mit Aufträgen versorgt wird.
#
# Durch die Aufteilung der Fertigung in einen bestandsgeregelten und einen nicht bestandsgeregelten Teil ermöglicht die Engpass-Steuerung eine effiziente Nutzung der vorhandenen Ressourcen. Sie sorgt dafür, dass das Engpassarbeitssystem kontinuierlich aus
# 19
# Die Organisationskultur beeinflusst maßgeblich das Verhalten der Mitarbeiterinnen und Mitarbeiter. Sie legt fest, welche Werte und Normen in der Arbeitsumgebung gelten und welche Verhaltensweisen akzeptiert werden. Eine positive Organisationskultur fördert ein respektvolles Miteinander und schafft ein Arbeitsklima, in dem Mobbing keinen Platz hat.
#
# Um Mobbing effektiv zu bekämpfen, ist es daher unerlässlich, die Organisationskultur zu stärken und weiterzuentwickeln. Dies kann durch gezielte Kulturarbeit und -entwicklung geschehen. Dabei geht es darum, die Werte und Normen der Organisation zu reflektieren und gegebenenfalls anzupassen. Durch klare Kommunikation und transparente Prozesse können Missverständnisse vermieden und Konflikte frühzeitig erkannt und gelöst werden.
#
# Ein weiterer wichtiger Aspekt der Kulturarbeit ist die Sensibilisierung der Mitarbeiterinnen und Mitarbeiter für das Thema Mobbing. Durch Schulungen und Workshops können sie für die Auswirkungen von Mobbing sensibilisiert
# 20
# In diesem Kapitel werden verschiedene Theorien und Modelle zur Erklärung der Werbewirkung vorgestellt und diskutiert. Dabei wird zunächst auf die klassischen Theorien der Werbewirkung eingegangen, wie beispielsweise das AIDA-Modell oder das Elaboration-Likelihood-Modell. Diese Theorien beschäftigen sich mit den psychologischen Prozessen, die bei der Verarbeitung von Werbebotschaften eine Rolle spielen.
#
# Des Weiteren werden auch neuere Ansätze zur Erklärung der Werbewirkung betrachtet, wie zum Beispiel das Modell der emotionalen Werbewirkung oder das Modell der kognitiven Verarbeitung von Werbung. Diese Ansätze berücksichtigen die Bedeutung von Emotionen und kognitionen bei der Werbewirkung und gehen davon aus, dass diese Faktoren eine entscheidende Rolle spielen.
#
# Zusätzlich werden auch Modelle zur Erklärung der Werbewirkung über die Zeit betrachtet. Hierbei wird untersucht, wie sich die Wirkung von Werbung im Laufe der Zeit verändert und welche Faktoren diese Ver
# 21
# Die erste Bewegung, die in Basel entstand, war die "Rettet den St. Johannspark"-Bewegung. Diese entstand, als die Stadtverwaltung Pläne ankündigte, einen Teil des St. Johannsparks für den Bau eines Einkaufszentrums zu überbauen. Die Bewohnerinnen und Bewohner des Stadtteils waren empört über diese Pläne, da der Park ein wichtiger Treffpunkt und Erholungsraum für die Gemeinschaft war. Sie organisierten Protestaktionen, Unterschriftensammlungen und informierten die Öffentlichkeit über die Bedeutung des Parks für das soziale Leben in der Stadt.
#
# Die zweite Bewegung, die in Basel entstand, war die "Kein Beton im Bruderholz"-Bewegung. Hierbei ging es um den geplanten Bau eines Wohnkomplexes auf einer Grünfläche im Stadtteil Bruderholz. Die Bewohnerinnen und Bewohner des Stadtteils waren besorgt über die Auswirkungen dieser Überbauung auf die Umwelt und die Lebensqualität in ihrem Viertel. Sie gr
# 22

# %%
connection_interrupted = False

if connection_interrupted:
    with open('gpt_generated_zeitonline_2.txt','r',encoding='utf-8') as f_in:

        content = f_in.read()
        entries = [entry.strip() for entry in content.split("\n")]
        text_entry = ''
        text_entries = []
        for entry in entries:
            if not entry.strip().isdigit():
                text_entry += entry
            else:
                text_entries.append(text_entry)
                text_entry = ''
            
    results = text_entries

# %%
with open(out_path,'a') as f_out:
    for result,prompt,max_gen_len in zip(results,all_prompts[:rpd],max_gen_lens[:rpd]):
        result_one_line = result.replace('\n', ' ')
        result_stripped = result_one_line.strip()
        cutted_result = cut_at_character_n(result_stripped,max_gen_len)
        result_complete_sentences = cut_at_last_complete_sentence(cutted_result)
        print(result_complete_sentences)
        text_len = len(result_complete_sentences)
        f_out.write(prompt+'\t'+str(result_complete_sentences)+'\t'+str(text_len)+'\t'+str(max_gen_len_str)+'\n')                               

#f_out.write(str(line_to_write) + '\n')                        
#line_index += 1
#print(line_index)
# Out:
# Das Tonusasymmetrie-Syndrom (TAS) ist eine häufige sensomotorische Störung bei Säuglingen, die auch als Säuglingsskoliose oder umgangssprachlich als KISS bekannt ist. Diese Störung ist ein typisches Beispiel für eine dysfunktionell bedingte Störung, bei der es zu einer Asymmetrie der Muskelspannung kommt. Durch diese Asymmetrie können verschiedene Probleme auftreten, wie zum Beispiel eine Verformung der Wirbelsäule oder eine eingeschränkte Beweglichkeit. Die entwicklungsneurologische Indikation ist eine neue Erweiterung des Konzepts der Manuellen Medizin, die es ermöglicht, Kinder mit sensomotorischen Störungen zu behandeln.
# Dazu gehören unter anderem Pressemitteilungen, Fachartikel, Informationsbroschüren, Social-Media-Kampagnen und direkte Kommunikation mit Ärztinnen und Ärzten. Die breite Öffentlichkeit wird über Werbung in verschiedenen Medienkanälen informiert, um das Bewusstsein für bestimmte Krankheiten oder Medikamente zu schärfen. Journalistinnen und Journalisten erhalten regelmäßig Pressemitteilungen und werden zu Pressekonferenzen eingeladen, um über aktuelle Entwicklungen in der Pharmabranche zu berichten.
# Sie suchen nach alternativen Heilmethoden oder natürlichen Heilmitteln, um ihre Beschwerden zu lindern.
# Comenius war der Überzeugung, dass die Menschheit durch die Ausübung brüderlicher Liebe in der Lage sein würde, eine Gesellschaft zu schaffen, die frei von Konflikten und Ungerechtigkeiten ist. Seine chiliastischen Vorstellungen über ein neues Millennium basierten auf der Idee, dass die Menschen durch ihre Liebe zueinander in der Lage sein würden, eine harmonische und gerechte Welt zu erschaffen. Um diese Prophezeiung des neuen Millenniums zu verwirklichen, betonte Comenius die Bedeutung der brüderlichen Liebe. Er glaubte, dass die Menschen lernen sollten, einander bedingungslos zu lieben und sich gegenseitig zu unterstützen. Nur durch diese liebevolle Beziehung könnten sie eine fast utopische Gesellschaft erreichen, in der Frieden und Gerechtigkeit herrschen. Comenius war sich bewusst, dass die Umsetzung dieser Vorstellungen nicht einfach sein würde. Es erforderte eine grundlegende Veränderung in der Denkweise und im Verhalten der Menschen.
# In Blumenbergs Analyse wird die Neugierde als eine grundlegende menschliche Eigenschaft betrachtet, die nicht nur den Drang nach Wissen hervorbringt, sondern auch die Fähigkeit des Menschen, sich über die Aufklärung hinaus zu erheben und die Neugierde in eine theoretische Ebene zu überführen. Diese offene und unbestimmte Natur der Neugierde ermöglicht es dem Menschen, sich ständig weiterzuentwickeln und neue Erkenntnisse zu gewinnen. Blumenberg betont, dass die Neugierde nicht nur ein individuelles Phänomen ist, sondern auch eine gesellschaftliche Dimension hat. Sie treibt den Menschen dazu an, sich mit anderen auszutauschen, Wissen zu teilen und gemeinsam nach Antworten auf Fragen zu suchen. Die Neugierde ist somit ein Motor für den Fortschritt und die Entwicklung der Gesellschaft.
# Die PR umfasst verschiedene therapeutische Maßnahmen, die darauf abzielen, die Lungenfunktion zu verbessern, die Atemmuskulatur zu stärken und die Lebensqualität der Betroffenen zu steigern. Dabei spielen sowohl körperliche als auch psychosoziale Aspekte eine wichtige Rolle. Durch regelmäßiges Training der Atemmuskulatur und gezielte Atemübungen kann die Lungenfunktion gesteigert werden. Dies führt zu einer besseren Sauerstoffversorgung des Körpers und einer erhöhten Belastbarkeit im Alltag. Zudem werden durch die PR auch die Atemwege gereinigt und Schleim abtransportiert, was zu einer Verringerung von Husten und Auswurf führt.
# Diese Gedenkstätten dienen dazu, an vergangene Ereignisse zu erinnern und die Erinnerung an die Opfer wachzuhalten. Sie sind ein wichtiger Teil des kollektiven Gedächtnisses und sollen dazu beitragen, dass sich solche schrecklichen Ereignisse nicht wiederholen. In Bosnien-Herzegowina und Kroatien gibt es aufgrund der Kriege in den 1990er Jahren eine Vielzahl solcher Gedenkstätten. Sie erinnern an die Opfer von Massakern, ethnischen Säuberungen und anderen Gräueltaten, die während dieser Zeit begangen wurden.
# Es wird erläutert, dass die „Mitte“-Studien darauf abzielen, die Einstellungen und Meinungen der Bevölkerung in Bezug auf rechtsextreme Tendenzen zu erfassen und zu analysieren. Dabei wird der Begriff „Mitte“ als eine Art Referenzpunkt verwendet, um die politische Orientierung und die Einstellungen der Menschen zu messen. Die Studien basieren auf einer breiten Datenbasis, die durch Umfragen und Befragungen erhoben wurde. Dabei wurden verschiedene Aspekte der rechtsextremen Einstellung untersucht, wie beispielsweise die Ablehnung von Minderheiten, die Zustimmung zu autoritären Strukturen und die nationalistische Gesinnung. Die Ergebnisse der Studien zeigen, dass rechtsextreme Einstellungen in Deutschland nach wie vor existieren und in Teilen der Bevölkerung verbreitet sind. Es wird deutlich, dass diese Einstellungen nicht nur in extremistischen Randgruppen anzutreffen sind, sondern auch in der sogenannten „Mitte“ der Gesellschaft.
# Das Assessment umfasst eine gründliche Anamnese, bei der der Physiotherapeut Informationen über die Krankheitsgeschichte, die aktuellen Beschwerden und die individuellen Ziele des Patienten sammelt. Dabei werden auch mögliche Risikofaktoren wie Vorerkrankungen, Medikamenteneinnahme oder berufliche Belastungen berücksichtigt. Zusätzlich werden klinische Tests durchgeführt, um die Beweglichkeit, Kraft, Koordination und Sensibilität des betroffenen Bereichs zu überprüfen. Hierbei kommen standardisierte Verfahren zum Einsatz, die eine objektive Beurteilung ermöglichen. Diese Tests helfen dabei, die Schwere der Erkrankung einzuschätzen und den Therapiebedarf festzulegen. Des Weiteren werden Fragebögen eingesetzt, um Informationen über die Lebensqualität, den Funktionsstatus und die Schmerzintensität des Patienten zu erfassen. Diese Fragebögen dienen als Ergänzung zu den klinischen Tests und ermöglichen eine umfassende Beurteilung des Gesundheitszustands.
# Heidenstam, auch bekannt als Carl Gustaf Verner von Heidenstam, war ein schwedischer Schriftsteller und Maler. Nach seinem Studium der Malerei in Paris und Rom unternahm er ausgedehnte Studienreisen, die ihn durch ganz Europa führten. Im Jahr 1912 wurde er Mitglied der Schwedischen Akademie, einer renommierten Institution für Literatur und Sprache.
# Nur so kannst Du sicherstellen, dass Du alle möglichen Lösungsansätze in Betracht ziehst und keine wichtigen Informationen übersehen wirst. Eine gründliche Vorbereitung ist der Schlüssel zum Erfolg. Dabei solltest Du nicht nur auf das Offensichtliche achten, sondern auch alternative Perspektiven einnehmen.
# eine chirurgische Intervention haben zu einer verbesserten Lebensqualität und einer Reduzierung von Komplikationen bei diesen Patienten geführt. Die Pharmakotherapie spielt eine entscheidende Rolle in der Behandlung neurogener Blasen bei Kindern und Jugendlichen. Durch die Verabreichung von Medikamenten wie Anticholinergika oder Alpha-Blockern kann die Blasenfunktion reguliert und die Symptome wie Harninkontinenz oder überaktive Blase gelindert werden. Diese Medikamente wirken auf die Muskulatur der Blase und ermöglichen eine bessere Kontrolle über die Blasenentleerung.
# Vaskuläre Tumoren sind abnormal wachsende Gewebe, die in zwei Hauptkategorien unterteilt werden: Angiome und Hamartome. Angiome sind Proliferationen von Endothelzellen, die das innere Auskleidungsgewebe der Blutgefäße bilden.
# Diese disruptiven Veränderungen sind durch technologische Innovationen und neue Geschäftsmodelle gekennzeichnet, die etablierte Unternehmen und Märkte grundlegend verändern können. Ein Beispiel dafür ist die Musikindustrie, die durch die Digitalisierung und den Aufstieg von Streaming-Diensten wie Spotify und Apple Music einen starken Wandel erfahren hat.
# Die Gründungsinitiativen müssen sich zunächst mit der Schulaufsichtsbehörde in Verbindung setzen und ihre Pläne für die Errichtung einer Freien Alternativschule vorlegen. Dabei müssen sie detaillierte Informationen über das pädagogische Konzept, die Lehrpläne und die organisatorischen Strukturen der Schule bereitstellen. Die Schulaufsicht prüft dann diese Unterlagen und entscheidet, ob die vorgelegten Pläne den gesetzlichen Anforderungen entsprechen. Oftmals kommt es während dieses Aushandlungsprozesses zu Diskussionen und Verhandlungen zwischen den Gründungsinitiativen und der Schulaufsicht.
# Hierbei muss der Tragwerksplaner verschiedene Faktoren berücksichtigen, wie zum Beispiel die Art der Belastung, die auf die Gebäudehülle wirkt, sowie die Beschaffenheit des Baugrunds. Zunächst erfolgt eine genaue Analyse der geplanten Nutzung des Gebäudes, um die erforderlichen Lasten zu ermitteln. Anschließend werden verschiedene Tragwerkssysteme in Betracht gezogen, die den Anforderungen gerecht werden.
# Quantenphänomene sind ein faszinierendes Gebiet der Forschung, das in den letzten Jahrzehnten zu bahnbrechenden Erkenntnissen geführt hat. Sie haben dazu beigetragen, unser Verständnis der Ordnungsmechanismen in Materialien mit korrelierten Elektronen zu verbessern und haben somit einen großen Einfluss auf die moderne Technik. Ein Beispiel für eine Innovation, die auf den Erkenntnissen der Quantenphänomene basiert, ist der Quantencomputer.
# Dieser beeindruckende Mensch, namens Dr. Friedrich Müller, öffnete Götz Rehn die Augen für eine völlig neue Welt jenseits der traditionellen Medizin. Durch zahlreiche Gespräche und Diskussionen erfuhr Götz von den Lehren der Anthroposophie, einer spirituellen Bewegung, die sich mit der Erforschung der nicht-sinnlichen Welt befasst.
# Bildung ist ein grundlegender Bestandteil jeder Gesellschaft und spielt eine entscheidende Rolle bei der Entwicklung und Entfaltung eines Individuums. Sie umfasst nicht nur den Erwerb von Wissen und Fertigkeiten, sondern auch die Vermittlung von Werthaltungen und Einstellungen, die für das Zusammenleben in einer Gesellschaft von Bedeutung sind. Die Bildung beginnt bereits in der frühen Kindheit und setzt sich während des gesamten Lebens fort. Sie erfolgt nicht nur in formalen Bildungseinrichtungen wie Schulen und Universitäten, sondern auch in informellen Kontexten wie Familie, Freizeitaktivitäten und der Interaktion mit anderen Menschen. Die Vermittlung von Werthaltungen spielt eine wichtige Rolle, da sie den Menschen dabei hilft, moralische und ethische Entscheidungen zu treffen.
# Der bestandsgeregelte Teil umfasst alle Arbeitsstationen vor dem Engpassarbeitssystem, die durch die Engpass-Steuerung gesteuert werden. Hier werden die Aufträge entsprechend der Verfügbarkeit von Material und Ressourcen freigegeben. Sobald das Engpassarbeitssystem einen Auftrag fertiggestellt hat, wird ein neuer Auftrag für die Fertigung freigegeben. Der nicht bestandsgeregelte Teil umfasst alle Arbeitsstationen nach dem Engpassarbeitssystem.
# Die Organisationskultur beeinflusst maßgeblich das Verhalten der Mitarbeiterinnen und Mitarbeiter. Sie legt fest, welche Werte und Normen in der Arbeitsumgebung gelten und welche Verhaltensweisen akzeptiert werden. Eine positive Organisationskultur fördert ein respektvolles Miteinander und schafft ein Arbeitsklima, in dem Mobbing keinen Platz hat.
# In diesem Kapitel werden verschiedene Theorien und Modelle zur Erklärung der Werbewirkung vorgestellt und diskutiert. Dabei wird zunächst auf die klassischen Theorien der Werbewirkung eingegangen, wie beispielsweise das AIDA-Modell oder das Elaboration-Likelihood-Modell. Diese Theorien beschäftigen sich mit den psychologischen Prozessen, die bei der Verarbeitung von Werbebotschaften eine Rolle spielen.
# Die erste Bewegung, die in Basel entstand, war die "Rettet den St. Johannspark"-Bewegung. Diese entstand, als die Stadtverwaltung Pläne ankündigte, einen Teil des St. Johannsparks für den Bau eines Einkaufszentrums zu überbauen. Die Bewohnerinnen und Bewohner des Stadtteils waren empört über diese Pläne, da der Park ein wichtiger Treffpunkt und Erholungsraum für die Gemeinschaft war.
